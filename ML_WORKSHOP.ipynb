# %%
import numpy as np
import matplotlib as plt

# %%
l=["1",2,3,4]
print(np.array(l, dtype=np.int64))
# Out:
# [1 2 3 4]

# %%
l1=[[1,2,3],[1,2,3]]
print(np.array(l1))
# Out:
# [[1 2 3]
#  [1 2 3]]

# %%
import pandas as pd
d={
    "a":[1,2,3],
    "p":[1,2,3]
}
print(pd.DataFrame(d)) # here list size of values must be same
# Out:
#    a  p
# 0  1  1
# 1  2  2
# 2  3  3
