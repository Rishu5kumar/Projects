# %%
# Install required packages in Colab
# !pip install cvzone==1.5.6
# !pip install ultralytics==8.0.26
# !pip install hydra-core>=1.2.0
# !pip install matplotlib>=3.2.2
# !pip install numpy>=1.18.5
# !pip install opencv-python==4.6.0.66
# !pip install Pillow>=7.1.2
# !pip install PyYAML>=5.3.1
# !pip install requests>=2.23.0
# !pip install scipy>=1.4.1
# !pip install torch>=1.7.0
# !pip install torchvision>=0.8.1
# !pip install tqdm>=4.64.0
# !pip install filterpy==1.4.5
# !pip install scikit-image==0.19.3
# !pip install lap==0.4.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 12.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
# ...
#   Using cached lap-0.4.0.tar.gz (1.5 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for lap
#   Running setup.py clean for lap
# Failed to build lap
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (lap)

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Load the YOLO model
model = YOLO('yolov8n.pt')

# Run the YOLO model on the input image
results = model("Image.png")

# Save the annotated image to disk
results.save(save_dir='/content/')  # Saves annotated image to /content/ directory

# Path to the saved annotated image
saved_image_path = '/content/predictions/Image.png'  # Adjust path based on YOLO's save directory structure

# Load the saved image using OpenCV
annotated_image = cv2.imread(saved_image_path)

# Display the annotated image using matplotlib
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for proper color display
plt.axis('off')  # Hide axes for better visualization
plt.show()
# Out:
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/Image.png: 640x640 5 persons, 7.9ms
# Speed: 0.5ms pre-process, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1667ce113ada> in <cell line: 12>()
#      10
#      11 # Save the annotated image to disk
# ---> 12 results.save(save_dir='/content/')  # Saves annotated image to /content/ directory
#      13
#      14 # Path to the saved annotated image
#
# AttributeError: 'list' object has no attribute 'save'
